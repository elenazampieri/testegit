# %% [markdown]
# Overview
#
# Goal: Send PIX data stored in Google Drive as .zip file to DWH
#
# Steps:
# 1. Import libraries
# 2. Create dfs to be inserted into PostgreSQL:
# 3. Insert df into PostgreSQL table
# 4. Move files to parent folder
# 5. Send message in brbank_recon_notify with daily PIX recon

# %% [markdown]
# # Import libraries

# %%
import pandas as pd              # create dfs
import numpy as np               # transform data
#import glob                      # union all files in one df
import psycopg2                  # connect to postgres
import psycopg2.extras as extras # insert df into postgres
import os                        # get path
import json                      # used to login in PostgreSQL
import sys                       # install libs
#import shutil                    # to move file from one folder to one level up after inserting data
from pydrive2.auth import GoogleAuth # authenticate google
from pydrive2.drive import GoogleDrive # use google drive methods
import datetime
import zipfile

from postgres_funcs import *
from pix_funcs import *
#from slackbot_funcs import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Create dfs to be inserted into PostgreSQL

# %% [markdown]
# ## Append all data from files in a Google Drive folder in one single df

# %% [markdown]
# ### Establish Google Drive authentication

# %%
gauth = GoogleAuth()
gauth.LocalWebserverAuth() # Creates local webserver and auto handles authentication.
#gauth.CommandLineAuth()
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=131180798743-f0496t9sf5v6i6t7geeahu6fjvbua1u1.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.

# %% [markdown]
# ### Set initial configs

# %%
## Set variables
team_drive_id = '0AMWVBx0Ntw8tUk9PVA'                      # team_drive_id to find files
pix_to_dwh_folder_id = '1PD2cMY4IsS_XIVe9k32N_PryYyy6l5Xr' # folder where PIX .zip files should be to be sent to DWH
df_list = []                                               # df list with data from files

# %% [markdown]
# ### Create file list with csvs in to_dwh folder that will turn into df

# %%
## Create file list with csvs that should turn into df
# Note that specific folder "to_dwh" id is specified as pix_to_dwh_folder_id 
file_list = drive.ListFile({'q': "'%s' in parents and trashed=false" % pix_to_dwh_folder_id, 
                            'corpora': 'teamDrive', 
                            'teamDriveId': team_drive_id, 
                            'includeTeamDriveItems': True,
                            'supportsTeamDrives': True
                           }).GetList()

for file in file_list:
    print('file:',file['title'])
# Out:
# file: JDPI_RELATORIO_FINANCEIRO_07022022_065117.zip

# %%
# Get all folders in Google Drive
drive_folders = drive.ListFile({'q':"mimeType='application/vnd.google-apps.folder' and trashed=false", 
                                    'corpora': 'teamDrive', 
                                    'teamDriveId': team_drive_id, 
                                    'includeTeamDriveItems': True, 
                                    'supportsTeamDrives': True
                                 }).GetList()
print('Folders:')
for num, folder in enumerate(drive_folders, start=1):
    print(num,'', folder['title'])
# Out:
# Folders:
# 1  previous
# 2  23 Open Banking
# 3  Stone
# 4  Pags
# 5  Banco Inter
# 6  Mercado Pago
# 7  txt
# 8  csv
# 9  Opt In
# 10  3. Opt In 2021 (new flow)
# 11  2. Account Creation 2022
# 12  Provisões
# 13  2022-02
# 14  202202
# 15  to_dwh
# 16  202202
# 17  to_dwh
# 18  to_dwh
# 19  Pagamentos Confirmados
# 20  NDs
# 21  Devolução de Pagamento
# 22  202202
# 23  to_dwh
# 24  02.2022
# 25  to_dwh
# 26  02.2022
# 27  2022-02 incentive amendment
# 28  853
# 29  645
# 30  2. Fevereiro
# 31  JD
# 32  Extrato diário 645 e 853 - 2021
# 33  Epay Regarga
# 34  01 Recon
# 35  00 Mismatches
# 36  12 TED-In/TED-Out
# 37  11 Mobile Topup
# 38  10 Bill Payments
# 39  09 Card Activation
# 40  Jan.2022
# 41  Opt In
# 42  Pix Home
# 43  videos
# 44  Q1
# 45  2022
# 46  12-2021
# 47  853
# 48  645
# 49  1. Janeiro
# 50  2021
# 51  2022
# 52  Provisões
# 53  to_dwh
# 54  01.2022
# 55  to_dwh
# 56  01.2022
# 57  2022-01
# 58  202201
# 59  to_dwh
# 60  202201
# 61  to_dwh
# 62  to_dwh
# 63  Pagamentos confirmados
# 64  Devolução de pagamento
# 65  ND
# 66  202201
# 67  String - V2, V3, V4
# 68  Dec.2021
# 69  Pix - Limits Data
# 70  Banking Home
# 71  Monitoria Pessoas Sancionadas
# 72  14 Auditoria
# 73  Untitled folder
# 74  Recordings
# 75  11-2021
# 76  853
# 77  645
# 78  12. Dezembro
# 79  Provisões
# 80  2021-12
# 81  202112
# 82  to_dwh
# 83  202112
# 84  to_dwh
# 85  to_dwh
# 86  Pagamentos confirmados
# 87  Devolução de pagamento
# 88  ND
# 89  202112
# 90  to_dwh
# 91  12.2021
# 92  to_dwh
# 93  12.2021
# 94  Auditoria
# 95  Lista Discador
# 96  Q4/2021
# 97  Share Support
# 98  02. CIP
# 99  01 Cabine simulação
# 100  TED-In
# 101  TED-out
# 102  Q4/2021 Card Activation Usability Test
# 103  Kill DoB
# 104  13 CashFlow
# 105  Recording
# 106  Novembro.2021
# 107  Bank Navigation and Pix Home on Merchant App
# 108  Off-site 2021
# 109  to_dwh
# 110  to_dwh
# 111  to_dwh
# 112  853
# 113  645
# 114  to_dwh
# 115  11.2021
# 116  to_dwh
# 117  11.2021
# 118  10-2021
# 119  Provisões
# 120  11. Novembro
# 121  2021-11
# 122  202111
# 123  202111
# 124  Pagamentos Confirmados
# 125  Devolução de Pagamento
# 126  ND
# 127  202111
# 128  Benchmarks
# 129  Demo
# 130  Q4
# 131  smoke test
# 132  Limited Accounts
# 133  Outubro.2021
# 134  txt
# 135  csv
# 136  txt
# 137  csv
# 138  Sales Reps PF
# 139  to_dwh
# 140  09-2021
# 141  to_dwh
# 142  to_dwh
# 143  Pagamentos confirmados
# 144  Devolução de pagamento
# 145  ND
# 146  645
# 147  853
# 148  10. Outubro
# 149  Provisões
# 150  2021-09
# 151  202110
# 152  202110
# 153  2021-10
# 154  202110
# 155  to_dwh
# 156  10.2021
# 157  to_dwh
# 158  10.2021
# 159  Special Return Mechanism
# 160  Code
# 161  Old versions
# 162  OLD
# 163  to_dwh
# 164  temp_dev
# 165  to_dwh
# 166  to_dwh
# 167  ND
# 168  Devoluções de Pagamento
# 169  Pagamentos confirmados
# 170  temp_dev
# 171  to_dwh
# 172  to_dwh
# 173  NDs
# 174  Devoluções de pagamento
# 175  Pagamentos confirmados
# 176  Devoluções de Pagamento
# 177  Pagamentos Confirmados
# 178  NDs
# 179  Handoff with QRCODE Flow
# 180  temp_dev
# 181  temp_dev
# 182  to_dwh
# 183  to_dwh
# 184  Devoluções de Pagamento
# 185  Pagamentos confirmados
# 186  NDs
# 187  temp_devol
# 188  99. Incidents
# 189  to_dwh
# 190  to_dwh
# 191  Devoluções de pagamento
# 192  Pagamentos confirmados
# 193  NDs
# 194  Example of Messages
# 195  Pagamentos confirmados
# 196  NDs
# 197  NDs
# 198  Pagamentos confirmados
# 199  ND
# 200  Pagamentos confirmados
# 201  Exemplos Mensagem de Erro CIP/RTM
# 202  [não usar] Instituição Credenciadora - A01 SELTEC (S+ Pag <> RTM <> CIP)
# 203  2021-09
# 204  SUMUP_XML_17.09.2021
# 205  SLC029
# 206  to_dwh
# 207  to_dwh
# 208  Pagamentos confirmados
# 209  Setembro.2021
# 210  Devolução de pagamento
# 211  2021/2022
# 212  2021/2022
# 213  2021/2022
# 214  Code
# 215  ND
# 216  Pix - QR Code on Card Reader Quick Interview
# 217  Code
# 218  Payout (receipts)
# 219  to_dwh
# 220  to_dwh
# 221  to_dwh
# 222  Pix - Pix-In Quick Interview
# 223  Pix - Special Return Mechanism
# 224  Code
# 225  03 HUB
# 226  Métricas
# 227  Unico - Reports
# 228  08 Recon CIP (645 e 853 Santander)
# 229  08-2021
# 230  to_dwh
# 231  202109
# 232  202109
# 233  202109
# 234  853
# 235  9. Setembro
# 236  to_dwh
# 237  to_dhw
# 238  09.2021
# 239  09.2021
# 240  Code
# 241  05. Termos Assinatura
# 242  04. SumUp SCD STR - A01 BACEN (STR <> JD)
# 243  03. Instituição Domicílio - A01 CIP SLC (RTM <> CIP <> SCD)
# 244  01. Documentos SumUp Pagamentos
# 245  00. Orçamentos & NFs & Boletos
# 246  2021/2022
# 247  Recordings
# 248  to_dwh
# 249  Global Instant Payouts Docs
# 250  853
# 251  Antigo
# 252  Serasa- Contrato
# 253  Code
# 254  Unico - Contrato
# 255  FCST & BHAG Q3.2021
# 256  CADOC 9010 e 9011
# 257  06.2021
# 258  12.2020
# 259  Agosto.2021
# 260  to_dwh
# 261  01.2021
# 262  to_dwh
# 263  02.2021
# 264  to_dwh
# 265  03.2021
# 266  to_dwh
# 267  to_dwh
# 268  to_dwh
# 269  to_dwh
# 270  Old
# 271  to_dwh
# 272  202108
# 273  07-2021
# 274  Old
# 275  2021-08
# 276  202108
# 277  202108
# 278  00. Certificados Digitais
# 279  2021-08
# 280  08.2021
# 281  to_dwh
# 282  08.2021
# 283  8. Agosto
# 284  Old
# 285  to_dwh
# 286  Old
# 287  Finansystech
# 288  Onboarding
# 289  Julho.2021
# 290  Demos
# 291  Mismatches
# 292  Q3
# 293  to_dwh
# 294  to_dwh
# 295  to_dwh
# 296  OLD
# 297  Code
# 298  2021-07
# 299  202107
# 300  2021-07
# 301  202107
# 302  202107
# 303  to_dwh
# 304  07.2021
# 305  07.2021
# 306  7. Julho
# 307  06-2021
# 308  10 STR
# 309  Bank Internal Transfer
# 310  CIP
# 311  SumUp Payments
# 312  Credit Card & Withdraw
# 313  Cash Out
# 314  TED
# 315  PIX
# 316  11 Audit
# 317  OLD
# 318  Infraction Reports
# 319  04.2021
# 320  05.2021
# 321  06.2021
# 322  to_dwh
# 323  Sale of receivables
# 324  08. Notifications
# 325  demos
# 326  07. Bank Statement
# 327  Reasons Recorded Calls (Bank - Saldo e Extrato)
# 328  Help video content
# 329  Comns
# 330  Comprovantes
# 331  Junho.2021
# 332  to_dwh
# 333  09 PIX
# 334  Think it - Product docs
# 335  Open Banking
# 336  Miscellaneous
# 337  to_dwh
# 338  QR Code scheduling
# 339  05-2021
# 340  06.2021
# 341  2021-06
# 342  202106
# 343  202106
# 344  2021-06
# 345  202106
# 346  Recordings
# 347  6. Junho
# 348  to_dwh
# 349  Scheduled QR Code payment
# 350  06 Depósito de Dinheiro
# 351  Scheduled QR Code payment
# 352  04 Instant Payouts
# 353  Support channels
# 354  Regulatory Demands Q2
# 355  Funding Project
# 356  Maio.2021
# 357  Hand-off protocol
# 358  Quick Overview on Current Process
# 359  Funding System Project
# 360  Treasury
# 361  Bankoffice
# 362  5. Maio
# 363  01 Finance
# 364  old
# 365  Pix Infraction Reports
# 366  Pix - Usability Testing
# 367  4. Abril
# 368  3. Março
# 369  2. Fevereiro
# 370  05.2021
# 371  8. Dashboard analysis
# 372  04-2021
# 373  2021-05
# 374  202105
# 375  2021-05
# 376  202105
# 377  202105
# 378  roteiros_pesquisas
# 379  estudos-stakeholders
# 380  Q22021
# 381  References
# 382  Discovery
# 383  MID - New Merchant payout changed
# 384  Waiting List
# 385  1. Account Creation 2021
# 386  W17.2021
# 387  Bradesco_Boleto_API
# 388  Cash Planning
# 389  W16.2021
# 390  Videos Backup
# 391  Bank Adoption Research
# 392  2. Payout Changes 2021
# 393  1. Account Creation 2021
# 394  Account Creation 2021
# 395  W15.2021
# 396  04.2021
# 397  Backup
# 398  W14.2021
# 399  W14.2021 (Não virou)
# 400  W13.2021 (Não virou)
# 401  OLD
# 402  03-2021
# 403  Demos
# 404  Q2
# 405  2021-04
# 406  Abr.2021
# 407  202104
# 408  2021-04
# 409  202104
# 410  202104
# 411  Payout Change 2021
# 412  7. Knowledge and Articles
# 413  6. NPS
# 414  Base Viradas
# 415  Untitled folder
# 416  Pix limit empty state
# 417  Pix limit onboarding
# 418  Pix limits
# 419  Online Marketing Case
# 420  Case Interview
# 421  0. Hiring
# 422  Prototype video
# 423  Pix Limit
# 424  Mar 2021
# 425  FUP Cartões, Contas e Comms
# 426  3. Research
# 427  Architecture
# 428  25. Auxilio DB to talk about Research
# 429  Ultima versão
# 430  01. Cash-In Flow Perceptions Interview
# 431  Online marketing Google case
# 432  4. Case Interview
# 433  Google Audiences
# 434  Complete profile
# 435  Mar.2021
# 436  2. Produto
# 437  1. Suporte
# 438  1. Grana que volta
# 439  4. Campaigns
# 440  5. Support & Others
# 441  3. Opt-Out
# 442  2.Opt-In | New Merchants
# 443  1. Team & Area
# 444  Backup
# 445  FIS
# 446  My Pix Limit
# 447  Product Design
# 448  Maps and Templates
# 449  9. Bonus How To Build A Quantitative Growth Model
# 450  8. Observing Changes And Evolving Your Strategy
# 451  7. Communicating Your Growth Strategy
# 452  6. Choosing your Growth Methods
# 453  5. Identifying your Growth Strategy and Horizons
# 454  4. Defining Your Growth Model
# 455  3. Macro Growth Loops
# 456  24. DB Bank Campaigns
# 457  Videos
# 458  Show and Tell
# 459  March 2021
# 460  23. Happy Hour Emails and cpfs
# 461  OLD
# 462  02-2021
# 463  W09.2021
# 464  2. Micro Growth Loops
# 465  1. Creating a Compound Growth Strategy
# 466  2. Reforge Advanced Growth Strategy
# 467  1. Negotiation & Influence (MIT)-20210302T134522Z-001
# 468  3. Courses
# 469  Bentley Convertible
# 470  Alplaus Supply Company
# 471  Carter Estate
# 472  67 Fish Pond Lane
# 473  Bakra Beverage
# 474  Cases
# 475  Slides
# 476  Transcripts
# 477  Papers
# 478  18. Negotiation _ Influence (MIT)
# 479  2021-03
# 480  2021-03
# 481  202103
# 482  202103
# 483  202103
# 484  2. Google Industry Reports and Audience Insights
# 485  Fev 2021
# 486  February 2021
# 487  22. Merchant Codes Payout Failed
# 488  W08.2021
# 489  2021-01
# 490  Q3
# 491  OLD
# 492  00. 100 Merchants Pilot
# 493  07 Extratos Accounting
# 494  12-2020
# 495  01-2021
# 496  OLD
# 497  Declaração PDV
# 498  Summary
# 499  00 Benchmarking
# 500  Refinements
# 501  1. Studies
# 502  Jan 2021
# 503  KYC
# 504  Fev.2021
# 505  W07.2021
# 506  December 2020
# 507  21. Analysis Boleto
# 508  W06.2021
# 509  Credz
# 510  Tutorials
# 511  App Security
# 512  30 Net Revenue
# 513  Legal
# 514  40 Credit Card
# 515  OLD
# 516  202102
# 517  2021-02
# 518  202102
# 519  2021-02
# 520  202102
# 521  Bank dev feedback
# 522  Jan.2021
# 523  Dec.2020
# 524  W04.2021
# 525  2020-12
# 526  Transações - Analítico
# 527  Demos
# 528  Videos
# 529  Illustrations
# 530  OLD
# 531  2021-01
# 532  OLD
# 533  2020-11
# 534  Q1
# 535  2021
# 536  2020
# 537  2020-12
# 538  Itau
# 539  Nubank
# 540  Benchmarks
# 541  SaveContacts
# 542  Discovery
# 543  2021-01
# 544  202101
# 545  202101
# 546  202011
# 547  202101
# 548  202012
# 549  202011
# 550  202010
# 551  202009
# 552  Masters
# 553  20. Support Impact Opt Outs
# 554  202012
# 555  Forecast 2021
# 556  19. SumUp Bank TPV stimation W50
# 557  202012
# 558  W51.2020
# 559  2020-12
# 560  18. Payout Changes After ATO Meeting
# 561  01 Recon
# 562  W50
# 563  old
# 564  Handover Carlos
# 565  05 All bank
# 566  04 ERD
# 567  03 New Opt Out batches
# 568  02 Health metrics 3.0 (Bruna)
# 569  01 Early Nights dashboard - Latest Early Night Dashboard published server
# 570  Extract Opt Out Novembro
# 571  Cálculo de Receita
# 572  2020-11
# 573  W49
# 574  W49
# 575  EN 30nov20
# 576  EN 23nov20
# 577  17. Shipping Reconciliation
# 578  16. Live Merchants November SumUp Bank
# 579  202009
# 580  202010
# 581  NFs
# 582  07 Net Revenue
# 583  Knowledge Sharing
# 584  Meetings and Data Control
# 585  Opt Outs
# 586  9. Important Online Files
# 587  2. New Merchants Dash
# 588  1. Plan vs. Actual
# 589  W48
# 590  W48
# 591  Images
# 592  EN 16nov20
# 593  EN 9nov20
# 594  30 Consumer
# 595  Edge Cases
# 596  W47
# 597  Screenshots
# 598  Pix - Desk Research
# 599  Pix - Exploration Interview
# 600  Pix - Heuristics
# 601  Pix - Benchmarking
# 602  W47
# 603  Daily report EN2
# 604  Historical EN reports
# 605  Daily report EN
# 606  UX Research
# 607  to_upload
# 608  ArquivosRetorno
# 609  W46.2020
# 610  8. NPS
# 611  Older
# 612  15. Shipping New Merchants 50 percent
# 613  W46
# 614  14. Analysis New Merchants to Convince Bernardo
# 615  W46
# 616  Monthly view Oct20
# 617  Shipping
# 618  W46
# 619  W45
# 620  W45 Bank Review
# 621  13. Janela pra virada de Payout
# 622  202011
# 623  202010
# 624  2020-10
# 625  12. Iniciativa Payout Failed
# 626  11. New Merchants Holiday
# 627  EN 2nov20
# 628  W45
# 629  10. Compliance Request
# 630  Viradas de Payout
# 631  Bases Amanda
# 632  W45
# 633  Shipping
# 634  Opt Outs
# 635  Cluster 2 - 25k Caixa
# 636  Cluster 3 - 35k caixa
# 637  DB November
# 638  2020-11
# 639  01 HUB
# 640  SCD
# 641  1-New versions
# 642  Opt out - target merchants
# 643  New merchants analysis
# 644  Health Metrics - Opt Out
# 645  9. New Merchants Churned
# 646  8. Merchants Caixa sem 24h
# 647  Organic
# 648  7. Waiting List
# 649  6. Refurbished Issue New Merchants
# 650  5. Acesso Status
# 651  EN 26oct20
# 652  4. Shipping Cards Delivery Prediction
# 653  Cluster 1 - 5k
# 654  Santander
# 655  Amex
# 656  W44
# 657  3. Weird Behavior New Merchants
# 658  .AU.g4INz
# 659  Opt out - experiments
# 660  Bank App
# 661  Rafaela
# 662  __pycache__
# 663  W42 TownHall
# 664  .ipynb_checkpoints
# 665  19oct20 - to be extracted
# 666  Originals
# 667  DB for Shipping
# 668  W42 Bases Facebook New Merchants
# 669  04 - PIX
# 670  EN 19oct20
# 671  Analysis PIX
# 672  19oct20 - already extracted
# 673  W43
# 674  demos
# 675  Extract PIX Caetano
# 676  01 - Opt Out
# 677  DB Jonathan
# 678  BankOffice
# 679  QR code flow
# 680  05 - Base and other queries
# 681  08 - Others
# 682  02 - Opt In
# 683  03 - New merchants
# 684  06 - Bank ERD
# 685  Extracts
# 686  Mega cohort
# 687  RFM
# 688  07 - RFM and behiavoral Clusters
# 689  New chart Town Hall
# 690  8 Clusters
# 691  2. Card Activation Lovato Bernardo
# 692  New daily batch - query
# 693  Mix clusters
# 694  Merchants DBs
# 695  W42
# 696  Mobile Apps
# 697  202010
# 698  Interchange
# 699  monthly recon
# 700  Cartão
# 701  .AU.9E9Gu
# 702  JDSPB - Message Layouts
# 703  Dashboards - Tableau Desktop
# 704  SumUp Bank - Pix (Merchant App)
# 705  4. Database Update
# 706  Q4
# 707  STR Message Layouts
# 708  Support Analysis
# 709  W41
# 710  Screenshots
# 711  UIQA
# 712  SumUp Bank - Pix
# 713  New-illustrations-onboarding
# 714  Certificados
# 715  Documentos
# 716  Valid
# 717  7. CRM Pix
# 718  Standalone Card Reader
# 719  Design - mockups
# 720  Old
# 721  W39
# 722  7. New merchants
# 723  6. Migration Acesso
# 724  5. Experiment 5 - Facebook Campaign
# 725  4. Experiment 4 -Readers with cards
# 726  3. Experiment 3 - aux emergencial
# 727  2. Experiment 2
# 728  1. Experiment 1
# 729  0. Analytics
# 730  Onboarding Pix
# 731  Ownership claim
# 732  Charge Pix
# 733  Key management
# 734  Pay Pix
# 735  Onboarding keys
# 736  Balance and Account details
# 737  Return Pix
# 738  Pix Screenshots for PMC support
# 739  Design - hand-off
# 740  Design - screenshots
# 741  202008
# 742  06 NFs - Revenues
# 743  AWS
# 744  Merchant App Images
# 745  22 Pix
# 746  Formulários RTM
# 747  Assinados
# 748  Elo
# 749  Formulários CIP
# 750  Master
# 751  Hiper
# 752  Cad Inst Domicilio
# 753  CIP/SCD
# 754  2020-09
# 755  202009
# 756  OLD
# 757  Metrics Overtime
# 758  OLD
# 759  Researches
# 760  other recons
# 761  05 Epay
# 762  202009
# 763  Legal
# 764  Onboarding
# 765  Research 3 groups databases
# 766  DBs for Ricci
# 767  Curated Queries Bank (WIP)
# 768  August
# 769  Images
# 770  W35 TownHall
# 771  6. Presentations
# 772  Payout Change
# 773  3. Account Queue Base
# 774  1. Merchant Sources First Experiments
# 775  5. Ad Hoc
# 776  Q3
# 777  Q2
# 778  Usage
# 779  Funnels
# 780  2. CRM Bases
# 781  TED
# 782  New Merchants Strategy
# 783  Q2
# 784  old
# 785  Total Numbers
# 786  2020-08
# 787  2020-07
# 788  4. Analytics
# 789  202008
# 790  202008
# 791  202008
# 792  2020-07
# 793  payout change
# 794  Lending
# 795  AndreC
# 796  BI
# 797  Git Hub Test
# 798  0 - Bank
# 799  .ipynb_checkpoints
# 800  EN Data
# 801  Cluster Analysis
# 802  Account Creation
# 803  Recon
# 804  Early Night
# 805  Adoption
# 806  3. Andre Handover
# 807  recon
# 808  NFs de Tarifas
# 809  .git
# 810  Bank_experiments_merchants
# 811  excel_answers
# 812  Chile
# 813  CADOC 4016
# 814  Bank
# 815  .ipynb_checkpoints
# 816  2. Account creation
# 817  Waiting list
# 818  Outbound calls
# 819  origin
# 820  origin
# 821  d8
# 822  heads
# 823  heads
# 824  logs
# 825  0c
# 826  d4
# 827  e1
# 828  32
# 829  71
# 830  cd
# 831  objects
# 832  2e
# 833  09
# 834  1b
# 835  7b
# 836  85
# 837  19
# 838  1e
# 839  0a
# 840  experiments
# 841  experiments
# 842  Excel
# 843  csv surveys
# 844  csv
# 845  pickle_files
# 846  Firebase
# 847  backups
# 848  backups
# 849  Incentive Contract
# 850  Receipts
# 851  Receipts
# 852  THs
# 853  Jupyter Notebooks
# 854  Teste Movimentação Conta SumUp
# 855  .ipynb_checkpoints
# 856  Envios ao BC
# 857  JD
# 858  Accounts Created
# 859  29
# 860  41
# 861  57
# 862  3c
# 863  11
# 864  1. Experiments
# 865  1. Adoption Merchant Base
# 866  12 Adoption
# 867  Extrato
# 868  04 Recon setup
# 869  Old Recon
# 870  02 Celcoin
# 871  01 Bank Statement
# 872  13 Lending
# 873  90 Accounting
# 874  Unit Economics
# 875  10 Planning
# 876  NDs
# 877  202007
# 878  202007
# 879  202007
# 880  95
# 881  6e
# 882  ff
# 883  56
# 884  54
# 885  ad
# 886  e0
# 887  cc
# 1304  2529534 - Edichardson Moura
# 1305  1809549 - Fernando Amorim
# 1306  3315427 - veronica da paixao
# 1307  4613397 - Washington Rodrigues da Silva
# 1308  600235 - Scarlet Coiffer
# 1309  Origem CIP
# 1310  1934722 - Cristiane
# 1311  787604 - Ramiro Peixoto da Silva Neto
# 1312  2101185 - Maria Aparecida Rodrigues
# 1313  03 Board Meetings
# 1314  3946455 - Adriana de Oliveira Carvalho
# 1315  1733350 - Francisca Daiana Viana Brasil
# 1316  1955526 - Vanderlei Stro
# 1317  2237154 - Domingos Sinda do Nascimento
# 1318  1879303 - Jaciane Gonçalina de Campos Curado
# 1319  1377440 - Cláudia Ferreira Torres
# 1320  2355193 - Jaciane Batista Amorim
# 1321  3300827	- Clayton Vilela
# 1322  541586 - Zelida Maria de Castro Paixão
# 1323  836653 - Peldza Karine Delgado Talaveira
# 1324  2080156 - Adriano Pereira da Silva
# 1325  2191919 - Gessika Roberta Pereira da Silva
# 1326  2337995 - Aline Fernandes de Amorim
# 1327  1107435 - Alexandre Ribeiro da Silva Neto
# 1328  02 Databases
# 1329  00 Merchant folders
# 1330  1558131 - Nathalia Silva Cavez
# 1331  1742218 - Daniel Reis Santana
# 1332  1358855 - Edson Rodrigues Leao
# 1333  1883825 - Edilene Costa
# 1334  4009613 - Debora de Alencar Silva
# 1335  1797317 - Dianatan Rodrigues dos Santos
# 1336  1926269 - Paulo Henrique da Silva
# 1337  05 Concierge
# 1338  ErroCompl
# 1339  ERR+Compl
# 1340  Origem ID
# 1341  ERR
# 1342  ErroRtm
# 1343  PRO
# 1344  RET
# 1345  21 Benchmarks
# 1346  02 Legal

# %%
## Overall:
## 1. Download .zip file, extract files in temp folder, delete .zipfile, move to parent folder in Google Drive
## 2. Go to temp folder and create a list of extracted files
## 3. Upload all files extracted to Google Drive

## 1. Download .zip file, extract files in temp folder, delete .zipfile, move to parent folder in Google Drive
for file in file_list: 
    
    # Create file in RAM
    fileDownloaded = drive.CreateFile({'id':file['id'],
                                   'corpora': 'teamDrive', 
                                    'teamDriveId': team_drive_id, 
                                    'includeItemsFromAllDrives': True,
                                    'supportsAllDrives': True
                                   })
    
    # Download file to current directory
    print('Downloading', file['title'])
    fileDownloaded.GetContentFile(file['title'])
    
    # Extract zip file to temp directory
    print('Extracting', file['title'])
    with zipfile.ZipFile(os.path.join(os.getcwd(),file['title']), 'r') as zip_ref:
        zip_ref.extractall(os.path.join(os.getcwd(), 'temp'))
    
    # Delete downloaded file
    print('Deleting', file['title'])
    os.remove(file['title'])
    
    # Get file folder_id
    folder_id = file['parents'][0]['id']
    
    for folder in drive_folders:

        # get the parent_folder_id 
        if (folder['id'] == folder_id):
            parent_folder_id = folder['parents'][0]['id']
            break

   # Change current folder to parent_folder
    file['parents'] = [{
                        'id': parent_folder_id,
                      }]
    
    # Upload to parent folder
    file.Upload(param={'supportsTeamDrives':True}) 
    print('File moved to parent folder')
# Out:
# Downloading JDPI_RELATORIO_FINANCEIRO_07022022_065117.zip
# Extracting JDPI_RELATORIO_FINANCEIRO_07022022_065117.zip
# Deleting JDPI_RELATORIO_FINANCEIRO_07022022_065117.zip
# File moved to parent folder

# %% [markdown]
# ### Create df, append to df_list and delete files in temp

# %%
# Go to temp folder and create a list of extracted files
os.chdir('temp')

# Create list of extracted files
extracted_file_list = []
extracted_file_list = [f for f in os.listdir(os.getcwd()) if os.path.isfile(os.path.join(os.getcwd(), f))]

# Create df from files that name starts with JDPI_RELATORIO_FINANCEIRO and delete all files extracted
for file in extracted_file_list:
    if file.startswith('JDPI_RELATORIO_FINANCEIRO'):
        df=pd.read_csv(file,index_col=None,header=0,sep=';')
        
        # Append to df_list
        df_list.append(df)
        print(file, 'appended to df_list')
    
    else:
        pass 
    
    # Delete file
    os.remove(file)
    print('file: ', file, 'removed')

# Go back to parent folder
os.chdir('..')
# Out:
# JDPI_RELATORIO_FINANCEIRO_07022022_065117.csv appended to df_list
# file:  JDPI_RELATORIO_FINANCEIRO_07022022_065117.csv removed
# file:  SUMARIO_JDPI_RELATORIO_FINANCEIRO_07022022_065117.csv removed
# C:\Users\elena.zampieri\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### Union all df and rename columns

# %%
## Union all dataframes
df_all_data = pd.concat(df_list, axis=0, ignore_index=True)

## Rename columns
df_all_data = df_all_data.rename(columns={"Data Hora": "date_day",
                                            "Tipo Operação": "operation",
                                            "IdFimAFim": "end_to_end_id",
                                            "IdFimAFimOriginal": "end_to_end_id_original",
                                            "NumCtrlSTR": "str_pix_control_number",
                                            "D/C": "direction",
                                            "Valor": "amount",
                                            "PSP Recebedor": "receiver_psp",
                                            "Agência Recebedora": "receiver_branch_number",
                                            "Conta Recebedora": "receiver_account_number",
                                            "CPF/CNPJ Recebedora": "receiver_national_document_id",
                                            "Nome Cliente Recebedor": "receiver_name",
                                            "PSP Pagador": "sender_psp",
                                            "Agência Pagadora": "sender_branch_number",
                                            "Conta Pagadora": "sender_account_number",
                                            "CPF/CNPJ Pagador": "sender_national_document_id",
                                            "Nome Cliente Pagador": "sender_name",
                                            "Situação": "status",
                                            "Tipo Iniciação": "sender_document_kind"
                                        }
                                )
## Print first rows
df_all_data.head()
# Out:
#                   date_day operation                     end_to_end_id  \
# 0  06/02/2022 02:59:53.461     Geral  E3724123020220206025938540991656
# 1  06/02/2022 02:59:52.289     Geral  E60746948202202060259A6500cVkWAo
# 2  06/02/2022 02:59:52.089     Geral  E00360305202202052359c9ca9ac1b8a
# 3  06/02/2022 02:59:51.140     Geral  E3724123020220206025937055153471
# 4  06/02/2022 02:59:27.459     Geral  E3724123020220206025909237248787
#
#   end_to_end_id_original  str_pix_control_number direction  amount  \
# 0                    NaN                     NaN    Debito    16.0
# 1                    NaN                     NaN   Credito    10.0
# 2                    NaN                     NaN   Credito   200.0
# 3                    NaN                     NaN    Debito    30.0
# 4                    NaN                     NaN    Debito    10.0
#
#    CNPJ Iniciador Pagamento  receiver_psp  receiver_branch_number  \
# 0                       NaN      360305.0                  3880.0
# 1                       NaN    37241230.0                     1.0
# 2                       NaN    37241230.0                     1.0
# 3                       NaN           0.0                   982.0
# 4                       NaN      416968.0                     1.0
#
#   receiver_account_number  receiver_national_document_id  \
# 0    12880000009701316725                   5.107728e+10
# 1              5432111499                   8.248388e+10
# 2              8332560120                   3.864985e+09
# 3                  928917                   3.791113e+13
# 4               141617870                   3.721705e+13
#
#                            receiver_name  sender_psp  sender_branch_number  \
# 0             LUCAS DE ALMEIDA CASSEMIRO  37241230.0                   1.0
# 1                                    NaN  60746948.0                  65.0
# 2                                    NaN    360305.0                1911.0
# 3              FLYTOP - GESTAO DE CONTRO  37241230.0                   1.0
# 4  JORGE VILLAS BOAS MARTINS 92095690753  37241230.0                   1.0
#
#    sender_account_number  sender_national_document_id  \
# 0           9.485729e+09                 5.107728e+10
# 1           3.958110e+05                 5.744527e+09
# 2           7.981726e+09                 2.770410e+09
# 3           7.108296e+09                 3.076089e+10
# 4           7.733346e+09                 1.751653e+10
#
#                        sender_name     status sender_document_kind
# 0       Lucas De Almeida Cassimiro  Efetivado                Chave
# 1             BARBARA TEREZA JORGE  Efetivado                Chave
# 2        CLEIDE FERNANDES DA SILVA  Efetivado                Chave
# 3  tania maria filgueiras da silva  Efetivado      QrCode Dinamico
# 4                   lucas cordeiro  Efetivado                Chave

# %%
filtered_df = df_all_data[(df_all_data['amount'].isnull())]
filtered_df.head()
# Out:
#      date_day  operation end_to_end_id end_to_end_id_original  \
# 6866      NaT  Efetivado         Chave                    NaN
#
#       str_pix_control_number direction  amount  CNPJ Iniciador Pagamento  \
# 6866                     NaN       NaN     NaN                       NaN
#
#       receiver_psp  receiver_branch_number receiver_account_number  \
# 6866           NaN                     NaN
#
#       receiver_national_document_id receiver_name  sender_psp  \
# 6866                            NaN           NaN         NaN
#
#       sender_branch_number  sender_account_number  \
# 6866                   NaN                    NaN
#
#       sender_national_document_id sender_name status sender_document_kind
# 6866                          NaN         NaN    NaN                  NaN

# %% [markdown]
# ## Transform and create columns

# %%
# Convert date_transaction from object to datetime
df_all_data['date_day'] = pd.to_datetime(df_all_data['date_day'], format='%d/%m/%Y %H:%M:%S.%f')

# Convert amount from reais to cents ($)
df_all_data['amount'] = df_all_data['amount']*100

# Convert from float to int
df_all_data['amount'] = df_all_data['amount'].round(0).astype(int)

# Create inserted_at column
df_all_data['inserted_at'] = pd.Timestamp('now')

# Convert from float to int -> pandas version doesn't accept null values in int data type (allows as Int64 but then there is a problem when inserting data to PostgreSQL as null values comes as <NA> not identified as null value)
df_all_data['receiver_psp'] = df_all_data['receiver_psp'].round(0).fillna(0).astype(int)
df_all_data['receiver_branch_number'] = df_all_data['receiver_branch_number'].round(0).fillna(0).astype(int)
df_all_data['receiver_account_number'] = pd.to_numeric(df_all_data['receiver_account_number'],errors='coerce').round(0).fillna(0).astype(int)
format_national_document_id(df=df_all_data, col_name='receiver_national_document_id')
df_all_data['sender_psp'] = df_all_data['sender_psp'].round(0).fillna(0).astype(int)
df_all_data['sender_branch_number'] = df_all_data['sender_branch_number'].round(0).fillna(0).astype(int)
df_all_data['sender_account_number'] = pd.to_numeric(df_all_data['sender_account_number'],errors='coerce').round(0).fillna(0).astype(int)
format_national_document_id(df=df_all_data, col_name='sender_national_document_id')


# Insert positive and negative in amount column
df_all_data['amount'] = df_all_data.apply(convert_to_sided_amount,axis=1)

# Removing status = 'Pendente'
df_all_data = df_all_data[df_all_data['status'] != 'Pendente']

# Create pix_key column
df_all_data['pix_key'] = df_all_data.apply(create_pix_key,axis=1)

# Drop duplicated values
#df_all_data = df_all_data.drop_duplicates(keep='last')

# Defining columns in case JD add/remove columns and make sure only DWH cols are inserted
pix_cols = ['date_day',
           'operation',
           'end_to_end_id',
           'end_to_end_id_original',
           'str_pix_control_number',
           'direction',
            'amount',
            'receiver_psp',
            'receiver_branch_number',
            'receiver_account_number',
            'receiver_national_document_id',
            'receiver_name',
            'sender_psp',
            'sender_branch_number',
            'sender_account_number',
            'sender_national_document_id',
            'sender_name',
            'status',
            'sender_document_kind',
            'inserted_at',
            'pix_key'
           ]

df_all_data = df_all_data[pix_cols]

## Printing first rows
df_all_data.head()

#df_all_data['colE'] = df_all_data['colB'].astype(str) + '-' + df_all_data['colD']
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# C:\Users\ELENA~1.ZAM\AppData\Local\Temp/ipykernel_24072/1133909553.py in <module>
#       6
#       7 # Convert from float to int
# ----> 8 df_all_data['amount'] = df_all_data['amount'].round(0).astype(int)
#       9
#      10 # Create inserted_at column
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1211     """
#    1212     if not np.isfinite(values).all():
# -> 1213         raise IntCastingNaNError(
#    1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# # Insert df into PostgreSQL table

# %% [markdown]
# ## Connect in sumup_dwh postgres database

# %%
# Import login credentials file
with open('postgres_login.json') as data_file:
    data = json.load(data_file)

user = data['user']
password =  data['password']

# Parameters to connect to postgres database
postgres_param_dic = {
    "host"      : "dwh.internal.sumup.com",
    "database"  : "sumup_dwh",
    "user"      : user,
    "password"  : password
}

# %% [markdown]
# ## Insert data into recon_jd_transactions

# %%
# %%time
# Connecting to the database
conn = connect_to_postgresql(params_dic=postgres_param_dic)

# Inserting jd data into recon_jd_transactions
insert_df_to_table(conn=conn, df=df_all_data, table='br_bank.recon_jd_transactions_raw')

# Close the connection
conn.close()

# %% [markdown]
# # Slackbot send daily recon

# %% [markdown]
# ## Import slack configs

# %%
from slack import WebClient
from slack.errors import SlackApiError

# %%
# Import login credentials file
with open('slackbot_token.json') as data_file:
    slackbot_config = json.load(data_file)

bot_token = slackbot_config['token']

# %%
# Define yesterday date
today = datetime.date.today()
yesterday = today - datetime.timedelta(days=1)

# Connect slackbot
client = WebClient(bot_token)

# %%
def send_slack_message(channel, text_message):
    try:
        response = client.chat_postMessage(
                                            channel = channel,
                                            text= text_message
                                            )
    except:
        pass

# %% [markdown]
# ## Consolidate data

# %%
# Connect to PostgreSQL, create df and close connection
with connect_to_postgresql(params_dic=postgres_param_dic) as conn:
    df_slack = pd.read_sql_query(consolidated_pix_query, conn)

# Create date column
df_slack['date'] = df_slack['date_day'].apply(lambda x: x.date())

df_slack.head()

# %% [markdown]
# ## Send message to brbank_recon_notify

# %%
# Send message: if it is Monday then send recon from Friday to Sunday, else send yesterday only
if today.weekday() == weekday_dic['Monday']:
    for count_day in range(3,0,-1):
        send_slack_message(channel='#brbank_recon_notify',                   
                           text_message = get_daily_pix_mismatch(df=df_slack,
                                                                 day=today-datetime.timedelta(days=count_day)
                                                                )
                          )
        
else:
    send_slack_message(channel='#brbank_recon_notify',
                       text_message = get_daily_pix_mismatch(df=df_slack,day=yesterday)
                      )

# %%
pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
